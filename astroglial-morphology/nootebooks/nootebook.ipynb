# %%
import numpy
from astroglial_morphology.binary_utils import load_binary_data
import matplotlib.pyplot as plt

# %%
from astroglial_morphology.binary_utils import load_binary_data
data_path = r"C:\Users\javid.rezai\YaksiLab\duygu\data\2025.08.23-glast_gcamp6s_5dpf_30mMptz_40min_xyt"

binary_data = load_binary_data(data_path+"/suite2p")
data = binary_data.data.data

first_frame = data[0]
plt.imshow(first_frame)
plt.show()
# Out:
# 2025-09-29 13:11:09 | astroglial_morphology.binary_utils | INFO | Loaded ops from C:\Users\javid.rezai\YaksiLab\duygu\data\2025.08.23-glast_gcamp6s_5dpf_30mMptz_40min_xyt\suite2p\plane0\ops.npy
# 2025-09-29 13:11:09 | astroglial_morphology.binary_utils | INFO | Loaded binary data from C:\Users\javid.rezai\YaksiLab\duygu\data\2025.08.23-glast_gcamp6s_5dpf_30mMptz_40min_xyt\suite2p\plane0\data.bin
